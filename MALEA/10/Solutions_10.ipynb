# %% [markdown]
# # Machine Learning Exercises 10
# This set of exercises are about getting familiar with performance metrics. Try to do as much as you can
# by hand, rather than using the computer, so that you get some practice for discussing the concepts at
# the oral exam.
#
#
# The important things to think about are what each metric actually measures and whether some types
# of errors are more problematic than others (the latter is naturally extremely application dependent!).
#
# When we specify a loss function/matrix, we exactly consider carefully how to penalise different types of
# errors. Classifiers can then be compared by the expected loss – this is what we have already often computed
# as the *test error*. For Bayes classifiers that uses 0-1 loss, the test error is simply the misclassification error
# (i.e. $1 – \text{Accuracy}$). So long as you are aware of whether the metric captures what you need, there is
# absolutely nothing wrong with using accuracy (or its complement, the *error rate*) as way of summarising
# or evaluating the performance of a classifier.
#
# You may also wish to use different metrics for building/training classifiers, selecting between them,
# and reporting results. In particular, the reporting will typically use a few easily comprehensible summaries
# of the classifier.

# %% [markdown]
# **Exercise 1.** Fill out the table and compute the macro-F1 score as well as the accuracy.
# ![ponies](attachment:image.png)

# %% [markdown]
# *Solution*:
# ![more](attachment:image.png)
#
# Macro: ~0.36
# Accuracy: 0.35

# %% [markdown]
# **Exercise 2.** Now look at the classification of just ponies and unicorns. Imagine that we have a classifier
# that leads to the following confusion matrix:
# ![image.png](attachment:image.png)
#
# a) For each of the two classes, find the precision, recall, and F1-score.
# ![image-2.png](attachment:image-2.png)
# An important take-home message from this exercise is that precision and recall consider the performance on a specific class, as does F1-score. So for a binary classifier, switching the two labels
# (positive/negative) will lead to different results and also different choices of classifiers if you use
# F1-score to select between them.
#
# b) Compute the macro-F1 score for the classifier. Is this the same if you switch the labels?
#
# c) What would be the test error (expected loss) for this classifier when loss is evaluated by the following
# loss matrix:
# $$
# L=\begin{bmatrix}0&2\\1&0\end{bmatrix}
# $$

# %% [markdown]
# *Solution*:
# a)
# ![image.png](attachment:image.png)

# %% [markdown]
# b) Macro = ~0.49. If we switch the labels the predictions are going to be completely different, so yeah it will change.

# %% [markdown]
# c) The penalty for false negatives is doubled so
# $$
# \frac{20+120}{30+60+20+50}=0.875
# $$

# %% [markdown]
# **Exercise 3**. Imagine that we apply two different classifiers to a balanced dataset with 100 instances
# in each of two classes. Classifier A has the highest accuracy, and classifyer B has the highest F1-score
# (considering the pony as the “positive” class). Give an example of what the two confusion matrices could
# look like.

# %% [markdown]
# *Solution*:
